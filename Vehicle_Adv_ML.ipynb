# %% [markdown]
# ||Case Study: Vehicle Advertisements Analysis ||
# -----

# %% [markdown]
# -------------------

# %% [markdown]
# -------------------

# %% [markdown]
# Section 1: Price Prediction
# ----

# %% [markdown]
# 1.	Data Cleaning & Preprocessing:
#
#     ○	Handle missing values appropriately.
#
#     ○	Encode categorical variables.
#
#     ○	Normalize/standardize numerical features if necessary.

# %%
import pandas as pd
import seaborn as sns
import os
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# %%
os.chdir('D:\DBDA\MACHINE LEARNING\Module_End')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_14648\4154991407.py:1: SyntaxWarning: invalid escape sequence '\D'
#   os.chdir('D:\DBDA\MACHINE LEARNING\Module_End')

# %%
df = pd.read_csv('vehicles.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258888 entries, 0 to 258887
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ad_title              258888 non-null  object
#  1   ad_description        258881 non-null  object
#  2   details               155505 non-null  object
#  3   slug                  258888 non-null  object
#  4   title                 258888 non-null  object
#  5   type                  258888 non-null  object
#  6   price                 255077 non-null  object
#  7   timestamp             258882 non-null  object
#  8   posted_date           258882 non-null  object
#  9   deactivation_date     258882 non-null  object
#  10  category              258888 non-null  object
#  11  parent_category       258888 non-null  object
#  12  location              258888 non-null  object
#  13  geo_region            258888 non-null  object
#  14  area                  258888 non-null  object
#  15  is_delivery_free      258888 non-null  bool
#  16  is_doorstep_delivery  258888 non-null  bool
#  17  is_dsd_applicable     258888 non-null  bool
#  18  is_member             249838 non-null  object
#  19  is_authorized_dealer  249838 non-null  object
#  20  is_featured_member    249838 non-null  object
#  21  is_verified           258888 non-null  bool
#  22  membership_level      258888 non-null  object
#  23  member_since          108634 non-null  object
#  24  properties            258888 non-null  object
#  25  user                  258888 non-null  object
# dtypes: bool(4), object(22)
# memory usage: 44.4+ MB

# %%
df.shape
# Out:
# (258888, 26)

# %%
df.isnull().sum()
# Out:
# ad_title                     0
# ad_description               7
# details                 103383
# slug                         0
# title                        0
# type                         0
# price                     3811
# timestamp                    6
# posted_date                  6
# deactivation_date            6
# category                     0
# parent_category              0
# location                     0
# geo_region                   0
# area                         0
# is_delivery_free             0
# is_doorstep_delivery         0
# is_dsd_applicable            0
# is_member                 9050
# is_authorized_dealer      9050
# is_featured_member        9050
# is_verified                  0
# membership_level             0
# member_since            150254
# properties                   0
# user                         0
# dtype: int64

# %%
pd.pandas.set_option('display.max_columns', None)
df.head()
# Out:
#                                             ad_title  \
# 0     Nissan Tiida Alternator  in Maharagama | ikman
# 1              Axio 165 Tail Light  in Kotte | ikman
# 2     Axio 165 / 161 Head light  in Kotte | ikman.lk
# 3   Vigo side step ( Foot board)  in Kottawa | ikman
# 4  Vigo Dickey Door Garnish Cover  in Kottawa | i...
#
#                                       ad_description details  \
# 0  **TISSA AUTO PARTS** Dealer of used Japanese m...     NaN
# 1  Imported from Japan \n\nRight side available \...     NaN
# 2  Imported from Japan \n\nAuto focus headlight a...     NaN
# 3  Hilux Vigo side step\nBrand New Thaiwan\nGood ...     NaN
# 4  Hilux Vigo ( 2005, 2009 ) dickey door garnish set     NaN
#
#                                                 slug  \
# 0         nissan-tiida-alternator-for-sale-colombo-3
# 1            axio-165-tail-light-for-sale-colombo-14
# 2           axio-165-161-head-light-for-sale-colombo
# 3         vigo-side-step-foot-board-for-sale-colombo
# 4  vigo-dickey-door-garnish-cover-for-sale-colombo-1
#
#                             title      type      price        timestamp  \
# 0         Nissan Tiida Alternator  for_sale  Rs 18,000  23 Feb 11:35 pm
# 1             Axio 165 Tail Light  for_sale  Rs 67,000   23 Feb 8:32 am
# 2       Axio 165 / 161 Head light  for_sale  Rs 85,000   01 Dec 8:27 pm
# 3    Vigo side step ( Foot board)  for_sale  Rs 47,000   04 Dec 2:47 pm
# 4  Vigo Dickey Door Garnish Cover  for_sale   Rs 9,000   08 Dec 9:28 am
#
#                  posted_date         deactivation_date  \
# 0  2023-02-23T23:35:10+05:30  2022-05-30T17:13:04.000Z
# 1  2023-02-23T08:32:44+05:30  2022-03-31T16:27:59.000Z
# 2  2022-12-01T20:27:49+05:30  2022-03-31T14:03:57.000Z
# 3  2022-12-04T14:47:27+05:30  2022-07-29T13:22:59.000Z
# 4  2022-12-08T09:28:04+05:30  2022-07-29T12:55:44.000Z
#
#                    category parent_category    location geo_region  \
# 0  Auto Parts & Accessories        Vehicles  Maharagama      LK-11
# 1  Auto Parts & Accessories        Vehicles       Kotte      LK-11
# 2  Auto Parts & Accessories        Vehicles       Kotte      LK-11
# 3  Auto Parts & Accessories        Vehicles     Kottawa      LK-11
# 4  Auto Parts & Accessories        Vehicles     Kottawa      LK-11
#
#                               area  is_delivery_free  is_doorstep_delivery  \
# 0  {'id': 1506, 'name': 'Colombo'}             False                 False
# 1  {'id': 1506, 'name': 'Colombo'}             False                 False
# 2  {'id': 1506, 'name': 'Colombo'}             False                 False
# 3  {'id': 1506, 'name': 'Colombo'}             False                 False
# 4  {'id': 1506, 'name': 'Colombo'}             False                 False
#
#    is_dsd_applicable is_member is_authorized_dealer is_featured_member  \
# 0              False      True                False              False
# 1              False      True                False              False
# 2              False      True                False              False
# 3              False      True                False              False
# 4              False      True                False              False
#
#    is_verified membership_level    member_since  \
# 0         True          premium  September 2019
# 1         True             plus       June 2018
# 2         True             plus       June 2018
# 3        False             plus   February 2017
# 4        False             plus   February 2017
#
#                                           properties  \
# 0  {'Condition': 'Reconditioned', 'Part or Access...
# 1  {'Condition': 'Reconditioned', 'Part or Access...
# 2  {'Condition': 'Reconditioned', 'Part or Access...
# 3  {'Condition': 'New', 'Part or Accessory Type':...
# 4  {'Condition': 'New', 'Part or Accessory Type':...
#
#                                                 user
# 0  a6681dea494390daa516a6d2bdcb36e08c318574a13413...
# 1  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 2  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 3  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...
# 4  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...

# %%
d1 = pd.DataFrame(df.properties)

# %%
d1.head()[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 d1.head()[1]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 1

# %% [markdown]
# ------------

# %% [markdown]
# a) Handling missing values

# %% [markdown]
# ----------

# %%
df.dropna(subset=['ad_description','timestamp','posted_date','deactivation_date'],inplace=True)

# %%
df.isnull().sum()
# Out:
# ad_title                     0
# ad_description               0
# details                 103382
# slug                         0
# title                        0
# type                         0
# price                     3811
# timestamp                    0
# posted_date                  0
# deactivation_date            0
# category                     0
# parent_category              0
# location                     0
# geo_region                   0
# area                         0
# is_delivery_free             0
# is_doorstep_delivery         0
# is_dsd_applicable            0
# is_member                 9049
# is_authorized_dealer      9049
# is_featured_member        9049
# is_verified                  0
# membership_level             0
# member_since            150243
# properties                   0
# user                         0
# dtype: int64

# %%
df = df.drop(['member_since','details'],axis=1)

# %%
df.isnull().sum()
# Out:
# ad_title                   0
# ad_description             0
# slug                       0
# title                      0
# type                       0
# price                   3811
# timestamp                  0
# posted_date                0
# deactivation_date          0
# category                   0
# parent_category            0
# location                   0
# geo_region                 0
# area                       0
# is_delivery_free           0
# is_doorstep_delivery       0
# is_dsd_applicable          0
# is_member               9049
# is_authorized_dealer    9049
# is_featured_member      9049
# is_verified                0
# membership_level           0
# properties                 0
# user                       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258875 entries, 0 to 258887
# Data columns (total 24 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ad_title              258875 non-null  object
#  1   ad_description        258875 non-null  object
#  2   slug                  258875 non-null  object
#  3   title                 258875 non-null  object
#  4   type                  258875 non-null  object
#  5   price                 255064 non-null  object
#  6   timestamp             258875 non-null  object
#  7   posted_date           258875 non-null  object
#  8   deactivation_date     258875 non-null  object
#  9   category              258875 non-null  object
#  10  parent_category       258875 non-null  object
#  11  location              258875 non-null  object
#  12  geo_region            258875 non-null  object
#  13  area                  258875 non-null  object
#  14  is_delivery_free      258875 non-null  bool
#  15  is_doorstep_delivery  258875 non-null  bool
#  16  is_dsd_applicable     258875 non-null  bool
#  17  is_member             249826 non-null  object
#  18  is_authorized_dealer  249826 non-null  object
#  19  is_featured_member    249826 non-null  object
#  20  is_verified           258875 non-null  bool
#  21  membership_level      258875 non-null  object
#  22  properties            258875 non-null  object
#  23  user                  258875 non-null  object
# dtypes: bool(4), object(20)
# memory usage: 42.5+ MB

# %%
df.shape
# Out:
# (258875, 24)

# %% [markdown]
# ------

# %% [markdown]
# Changing price column to float

# %% [markdown]
# ------

# %%
df['price'] = pd.to_numeric(df['price'].str.replace('Rs', '').str.replace(',', ''), errors='coerce')

# %%
df['price'].fillna(df['price'].median(), inplace=True)
# Out:
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\1576110267.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].fillna(df['price'].median(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258875 entries, 0 to 258887
# Data columns (total 24 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ad_title              258875 non-null  object
#  1   ad_description        258875 non-null  object
#  2   slug                  258875 non-null  object
#  3   title                 258875 non-null  object
#  4   type                  258875 non-null  object
#  5   price                 258875 non-null  float64
#  6   timestamp             258875 non-null  object
#  7   posted_date           258875 non-null  object
#  8   deactivation_date     258875 non-null  object
#  9   category              258875 non-null  object
#  10  parent_category       258875 non-null  object
#  11  location              258875 non-null  object
#  12  geo_region            258875 non-null  object
#  13  area                  258875 non-null  object
#  14  is_delivery_free      258875 non-null  bool
#  15  is_doorstep_delivery  258875 non-null  bool
#  16  is_dsd_applicable     258875 non-null  bool
#  17  is_member             249826 non-null  object
#  18  is_authorized_dealer  249826 non-null  object
#  19  is_featured_member    249826 non-null  object
#  20  is_verified           258875 non-null  bool
#  21  membership_level      258875 non-null  object
#  22  properties            258875 non-null  object
#  23  user                  258875 non-null  object
# dtypes: bool(4), float64(1), object(19)
# memory usage: 42.5+ MB

# %%
df['is_member'].fillna(False, inplace=True)
df['is_authorized_dealer'].fillna(False, inplace=True)
df['is_featured_member'].fillna(False, inplace=True)
# Out:
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\822425805.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['is_member'].fillna(False, inplace=True)
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\822425805.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['is_member'].fillna(False, inplace=True)
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\822425805.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['is_authorized_dealer'].fillna(False, inplace=True)
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\822425805.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['is_authorized_dealer'].fillna(False, inplace=True)
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\822425805.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['is_featured_member'].fillna(False, inplace=True)
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\822425805.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['is_featured_member'].fillna(False, inplace=True)

# %%
df.isnull().sum()
# Out:
# ad_title                0
# ad_description          0
# slug                    0
# title                   0
# type                    0
# price                   0
# timestamp               0
# posted_date             0
# deactivation_date       0
# category                0
# parent_category         0
# location                0
# geo_region              0
# area                    0
# is_delivery_free        0
# is_doorstep_delivery    0
# is_dsd_applicable       0
# is_member               0
# is_authorized_dealer    0
# is_featured_member      0
# is_verified             0
# membership_level        0
# properties              0
# user                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258875 entries, 0 to 258887
# Data columns (total 24 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ad_title              258875 non-null  object
#  1   ad_description        258875 non-null  object
#  2   slug                  258875 non-null  object
#  3   title                 258875 non-null  object
#  4   type                  258875 non-null  object
#  5   price                 258875 non-null  float64
#  6   timestamp             258875 non-null  object
#  7   posted_date           258875 non-null  object
#  8   deactivation_date     258875 non-null  object
#  9   category              258875 non-null  object
#  10  parent_category       258875 non-null  object
#  11  location              258875 non-null  object
#  12  geo_region            258875 non-null  object
#  13  area                  258875 non-null  object
#  14  is_delivery_free      258875 non-null  bool
#  15  is_doorstep_delivery  258875 non-null  bool
#  16  is_dsd_applicable     258875 non-null  bool
#  17  is_member             258875 non-null  bool
#  18  is_authorized_dealer  258875 non-null  bool
#  19  is_featured_member    258875 non-null  bool
#  20  is_verified           258875 non-null  bool
#  21  membership_level      258875 non-null  object
#  22  properties            258875 non-null  object
#  23  user                  258875 non-null  object
# dtypes: bool(7), float64(1), object(16)
# memory usage: 37.3+ MB

# %%
df['posted_date'] = pd.to_datetime(df['posted_date'], errors='coerce')
df['deactivation_date'] = pd.to_datetime(df['deactivation_date'], errors='coerce')
df['posted_date'] = df['posted_date'].dt.date
df['deactivation_date'] = df['deactivation_date'].dt.date

# %%
idx = np.where(df.posted_date>df.deactivation_date)[0]
df['posted_date'].iloc[idx], df['deactivation_date'].iloc[idx] = df['deactivation_date'].iloc[idx], df['posted_date'].iloc[idx]
# Out:
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\2545758157.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['posted_date'].iloc[idx], df['deactivation_date'].iloc[idx] = df['deactivation_date'].iloc[idx], df['posted_date'].iloc[idx]
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\2545758157.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['posted_date'].iloc[idx], df['deactivation_date'].iloc[idx] = df['deactivation_date'].iloc[idx], df['posted_date'].iloc[idx]
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\2545758157.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['posted_date'].iloc[idx], df['deactivation_date'].iloc[idx] = df['deactivation_date'].iloc[idx], df['posted_date'].iloc[idx]
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\2545758157.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['posted_date'].iloc[idx], df['deactivation_date'].iloc[idx] = df['deactivation_date'].iloc[idx], df['posted_date'].iloc[idx]

# %%
df.head()
# Out:
#                                             ad_title  \
# 0     Nissan Tiida Alternator  in Maharagama | ikman
# 1              Axio 165 Tail Light  in Kotte | ikman
# 2     Axio 165 / 161 Head light  in Kotte | ikman.lk
# 3   Vigo side step ( Foot board)  in Kottawa | ikman
# 4  Vigo Dickey Door Garnish Cover  in Kottawa | i...
#
#                                       ad_description  \
# 0  **TISSA AUTO PARTS** Dealer of used Japanese m...
# 1  Imported from Japan \n\nRight side available \...
# 2  Imported from Japan \n\nAuto focus headlight a...
# 3  Hilux Vigo side step\nBrand New Thaiwan\nGood ...
# 4  Hilux Vigo ( 2005, 2009 ) dickey door garnish set
#
#                                                 slug  \
# 0         nissan-tiida-alternator-for-sale-colombo-3
# 1            axio-165-tail-light-for-sale-colombo-14
# 2           axio-165-161-head-light-for-sale-colombo
# 3         vigo-side-step-foot-board-for-sale-colombo
# 4  vigo-dickey-door-garnish-cover-for-sale-colombo-1
#
#                             title      type    price        timestamp  \
# 0         Nissan Tiida Alternator  for_sale  18000.0  23 Feb 11:35 pm
# 1             Axio 165 Tail Light  for_sale  67000.0   23 Feb 8:32 am
# 2       Axio 165 / 161 Head light  for_sale  85000.0   01 Dec 8:27 pm
# 3    Vigo side step ( Foot board)  for_sale  47000.0   04 Dec 2:47 pm
# 4  Vigo Dickey Door Garnish Cover  for_sale   9000.0   08 Dec 9:28 am
#
#   posted_date deactivation_date                  category parent_category  \
# 0  2022-05-30        2023-02-23  Auto Parts & Accessories        Vehicles
# 1  2022-03-31        2023-02-23  Auto Parts & Accessories        Vehicles
# 2  2022-03-31        2022-12-01  Auto Parts & Accessories        Vehicles
# 3  2022-07-29        2022-12-04  Auto Parts & Accessories        Vehicles
# 4  2022-07-29        2022-12-08  Auto Parts & Accessories        Vehicles
#
#      location geo_region                             area  is_delivery_free  \
# 0  Maharagama      LK-11  {'id': 1506, 'name': 'Colombo'}             False
# 1       Kotte      LK-11  {'id': 1506, 'name': 'Colombo'}             False
# 2       Kotte      LK-11  {'id': 1506, 'name': 'Colombo'}             False
# 3     Kottawa      LK-11  {'id': 1506, 'name': 'Colombo'}             False
# 4     Kottawa      LK-11  {'id': 1506, 'name': 'Colombo'}             False
#
#    is_doorstep_delivery  is_dsd_applicable  is_member  is_authorized_dealer  \
# 0                 False              False       True                 False
# 1                 False              False       True                 False
# 2                 False              False       True                 False
# 3                 False              False       True                 False
# 4                 False              False       True                 False
#
#    is_featured_member  is_verified membership_level  \
# 0               False         True          premium
# 1               False         True             plus
# 2               False         True             plus
# 3               False        False             plus
# 4               False        False             plus
#
#                                           properties  \
# 0  {'Condition': 'Reconditioned', 'Part or Access...
# 1  {'Condition': 'Reconditioned', 'Part or Access...
# 2  {'Condition': 'Reconditioned', 'Part or Access...
# 3  {'Condition': 'New', 'Part or Accessory Type':...
# 4  {'Condition': 'New', 'Part or Accessory Type':...
#
#                                                 user
# 0  a6681dea494390daa516a6d2bdcb36e08c318574a13413...
# 1  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 2  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 3  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...
# 4  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...

# %% [markdown]
# ---------

# %% [markdown]
# b)	Encode categorical variables.

# %% [markdown]
# -------

# %%
df.shape
# Out:
# (258875, 24)

# %%
df_new1 = pd.DataFrame(df)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df_new1.head()
# Out:
#                                             ad_title  \
# 0     Nissan Tiida Alternator  in Maharagama | ikman
# 1              Axio 165 Tail Light  in Kotte | ikman
# 2     Axio 165 / 161 Head light  in Kotte | ikman.lk
# 3   Vigo side step ( Foot board)  in Kottawa | ikman
# 4  Vigo Dickey Door Garnish Cover  in Kottawa | i...
#
#                                       ad_description  \
# 0  **TISSA AUTO PARTS** Dealer of used Japanese m...
# 1  Imported from Japan \n\nRight side available \...
# 2  Imported from Japan \n\nAuto focus headlight a...
# 3  Hilux Vigo side step\nBrand New Thaiwan\nGood ...
# 4  Hilux Vigo ( 2005, 2009 ) dickey door garnish set
#
#                                                 slug  \
# 0         nissan-tiida-alternator-for-sale-colombo-3
# 1            axio-165-tail-light-for-sale-colombo-14
# 2           axio-165-161-head-light-for-sale-colombo
# 3         vigo-side-step-foot-board-for-sale-colombo
# 4  vigo-dickey-door-garnish-cover-for-sale-colombo-1
#
#                             title      type    price        timestamp  \
# 0         Nissan Tiida Alternator  for_sale  18000.0  23 Feb 11:35 pm
# 1             Axio 165 Tail Light  for_sale  67000.0   23 Feb 8:32 am
# 2       Axio 165 / 161 Head light  for_sale  85000.0   01 Dec 8:27 pm
# 3    Vigo side step ( Foot board)  for_sale  47000.0   04 Dec 2:47 pm
# 4  Vigo Dickey Door Garnish Cover  for_sale   9000.0   08 Dec 9:28 am
#
#   posted_date deactivation_date                  category parent_category  \
# 0  2022-05-30        2023-02-23  Auto Parts & Accessories        Vehicles
# 1  2022-03-31        2023-02-23  Auto Parts & Accessories        Vehicles
# 2  2022-03-31        2022-12-01  Auto Parts & Accessories        Vehicles
# 3  2022-07-29        2022-12-04  Auto Parts & Accessories        Vehicles
# 4  2022-07-29        2022-12-08  Auto Parts & Accessories        Vehicles
#
#      location geo_region                             area  is_delivery_free  \
# 0  Maharagama      LK-11  {'id': 1506, 'name': 'Colombo'}             False
# 1       Kotte      LK-11  {'id': 1506, 'name': 'Colombo'}             False
# 2       Kotte      LK-11  {'id': 1506, 'name': 'Colombo'}             False
# 3     Kottawa      LK-11  {'id': 1506, 'name': 'Colombo'}             False
# 4     Kottawa      LK-11  {'id': 1506, 'name': 'Colombo'}             False
#
#    is_doorstep_delivery  is_dsd_applicable  is_member  is_authorized_dealer  \
# 0                 False              False       True                 False
# 1                 False              False       True                 False
# 2                 False              False       True                 False
# 3                 False              False       True                 False
# 4                 False              False       True                 False
#
#    is_featured_member  is_verified membership_level  \
# 0               False         True          premium
# 1               False         True             plus
# 2               False         True             plus
# 3               False        False             plus
# 4               False        False             plus
#
#                                           properties  \
# 0  {'Condition': 'Reconditioned', 'Part or Access...
# 1  {'Condition': 'Reconditioned', 'Part or Access...
# 2  {'Condition': 'Reconditioned', 'Part or Access...
# 3  {'Condition': 'New', 'Part or Accessory Type':...
# 4  {'Condition': 'New', 'Part or Accessory Type':...
#
#                                                 user
# 0  a6681dea494390daa516a6d2bdcb36e08c318574a13413...
# 1  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 2  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 3  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...
# 4  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...

# %%
categorical_features = ['ad_title',	'ad_description',	'slug',	'title',	'type',	'timestamp',	'posted_date',	'deactivation_date',	'category',	'parent_category',	'location',	'geo_region',	'area',	'is_delivery_free',	'is_doorstep_delivery',	'is_dsd_applicable',	'is_member',	'is_authorized_dealer',	'is_featured_member',	'is_verified',	'membership_level',	'properties',	'user']
label_encoders = {col: LabelEncoder() for col in categorical_features}

for col in categorical_features:
    df_new1[col] = label_encoders[col].fit_transform(df_new1[col])

# %% [markdown]
# --------

# %% [markdown]
# c) Normalize/standardize numerical features if necessary.

# %% [markdown]
# -----

# %%
numerical_features = ['price']
scaler = StandardScaler()
df_new1[numerical_features] = scaler.fit_transform(df_new1[numerical_features])

# %% [markdown]
# 2.	Feature Selection:
#
#     ○	Perform correlation analysis to identify relevant features.
#
#     ○	Apply feature selection techniques such as Recursive Feature Elimination (RFE) or Lasso Regression.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15, 10))
correlation_matrix = df_new1.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='inferno')
plt.show()

# %%
df_new1.drop(columns=['is_delivery_free','is_doorstep_delivery','parent_category','ad_description','is_dsd_applicable'], inplace=True)

# %%
df_new1.shape
# Out:
# (258875, 19)

# %% [markdown]
# ------------
#
# dropping unneccesary columns
#
# -------------

# %%
df_new1.head()
# Out:
#    ad_title    slug   title  type     price  timestamp  posted_date  \
# 0    121151  160724   67713     0 -0.278796      85996          216
# 1     11730   13558    9903     0 -0.272043      86563          156
# 2     11712   13535    9886     0 -0.269562       1362          156
# 3    189641  246035  109459     0 -0.274799      14158          273
# 4    189613  246012  109432     0 -0.280036      31514          273
#
#    deactivation_date  category  location  geo_region  area  is_member  \
# 0                120         0       127           1     4          1
# 1                120         0       120           1     4          1
# 2                 36         0       120           1     4          1
# 3                 39         0       119           1     4          1
# 4                 43         0       119           1     4          1
#
#    is_authorized_dealer  is_featured_member  is_verified  membership_level  \
# 0                     0                   0            1                 2
# 1                     0                   0            1                 1
# 2                     0                   0            1                 1
# 3                     0                   0            0                 1
# 4                     0                   0            0                 1
#
#    properties   user
# 0      134989  52581
# 1      135073  29647
# 2      135081  29647
# 3      134510  31393
# 4      134510  31393

# %%
correlation_matrix = df_new1.corr()
correlation_matrix
# Out:
#                       ad_title      slug     title      type     price  \
# ad_title              1.000000  0.932612  0.997849  0.025237  0.070067
# slug                  0.932612  1.000000  0.927819  0.015219  0.076612
# title                 0.997849  0.927819  1.000000  0.024833  0.068979
# type                  0.025237  0.015219  0.024833  1.000000 -0.016215
# price                 0.070067  0.076612  0.068979 -0.016215  1.000000
# timestamp             0.004792  0.005436  0.004672  0.005180  0.002238
# posted_date          -0.039905 -0.029663 -0.039543  0.010280  0.011966
# deactivation_date    -0.020018 -0.010314 -0.020047  0.009205 -0.009118
# category             -0.093939 -0.063958 -0.094040  0.028072  0.072687
# location              0.007548  0.001861  0.008104 -0.011850 -0.046519
# geo_region           -0.043345 -0.038600 -0.044072  0.028976 -0.042363
# area                 -0.065613 -0.060461 -0.065965  0.015054 -0.054129
# is_member             0.090414  0.069138  0.092351 -0.052121  0.039286
# is_authorized_dealer  0.016427  0.015315  0.016519 -0.000874  0.016154
# is_featured_member    0.003403  0.003696  0.003481 -0.000493  0.019353
# is_verified           0.105589  0.083792  0.106259 -0.039748  0.056238
# membership_level      0.084794  0.065166  0.086319 -0.050457  0.043792
# properties            0.377515  0.337814  0.371199  0.067729  0.021337
# user                  0.002049  0.005089  0.002822 -0.004308  0.005768
#
#                       timestamp  posted_date  deactivation_date  category  \
# ad_title               0.004792    -0.039905          -0.020018 -0.093939
# slug                   0.005436    -0.029663          -0.010314 -0.063958
# title                  0.004672    -0.039543          -0.020047 -0.094040
# type                   0.005180     0.010280           0.009205  0.028072
# price                  0.002238     0.011966          -0.009118  0.072687
# timestamp              1.000000    -0.021846          -0.012385 -0.031726
# posted_date           -0.021846     1.000000           0.819094  0.091731
# deactivation_date     -0.012385     0.819094           1.000000  0.017517
# category              -0.031726     0.091731           0.017517  1.000000
# location               0.005585    -0.010939          -0.008639 -0.066656
# geo_region            -0.021974     0.035408           0.014467  0.198420
# area                  -0.022951     0.038305           0.014199  0.175334
# is_member              0.037758    -0.088387          -0.021835 -0.343898
# is_authorized_dealer  -0.008781    -0.002199          -0.003712  0.001171
# is_featured_member    -0.000491    -0.000324          -0.001323 -0.000085
# is_verified            0.029171    -0.112283          -0.043550 -0.286976
# membership_level       0.038842    -0.100369          -0.032664 -0.291554
# properties             0.026065    -0.063521          -0.011988 -0.664129
# user                   0.005924     0.006960           0.018137 -0.015006
#
#                       location  geo_region      area  is_member  \
# ad_title              0.007548   -0.043345 -0.065613   0.090414
# slug                  0.001861   -0.038600 -0.060461   0.069138
# title                 0.008104   -0.044072 -0.065965   0.092351
# type                 -0.011850    0.028976  0.015054  -0.052121
# price                -0.046519   -0.042363 -0.054129   0.039286
# timestamp             0.005585   -0.021974 -0.022951   0.037758
# posted_date          -0.010939    0.035408  0.038305  -0.088387
# deactivation_date    -0.008639    0.014467  0.014199  -0.021835
# category             -0.066656    0.198420  0.175334  -0.343898
# location              1.000000   -0.015392  0.189128   0.042006
# geo_region           -0.015392    1.000000  0.310568  -0.306464
# area                  0.189128    0.310568  1.000000  -0.275172
# is_member             0.042006   -0.306464 -0.275172   1.000000
# is_authorized_dealer -0.014919   -0.007526 -0.008561   0.016609
# is_featured_member    0.005496   -0.004245 -0.004829   0.009368
# is_verified           0.052947   -0.233942 -0.242214   0.730542
# membership_level      0.035633   -0.298135 -0.265541   0.952283
# properties            0.049089   -0.191274 -0.188131   0.340147
# user                 -0.018519    0.003751  0.006613   0.029623
#
#                       is_authorized_dealer  is_featured_member  is_verified  \
# ad_title                          0.016427            0.003403     0.105589
# slug                              0.015315            0.003696     0.083792
# title                             0.016519            0.003481     0.106259
# type                             -0.000874           -0.000493    -0.039748
# price                             0.016154            0.019353     0.056238
# timestamp                        -0.008781           -0.000491     0.029171
# posted_date                      -0.002199           -0.000324    -0.112283
# deactivation_date                -0.003712           -0.001323    -0.043550
# category                          0.001171           -0.000085    -0.286976
# location                         -0.014919            0.005496     0.052947
# geo_region                       -0.007526           -0.004245    -0.233942
# area                             -0.008561           -0.004829    -0.242214
# is_member                         0.016609            0.009368     0.730542
# is_authorized_dealer              1.000000           -0.000096     0.021834
# is_featured_member               -0.000096            1.000000     0.012315
# is_verified                       0.021834            0.012315     1.000000
# membership_level                  0.018962            0.010695     0.737645
# properties                        0.010156            0.002010     0.296904
# user                              0.010350            0.002344     0.028372
#
#                       membership_level  properties      user
# ad_title                      0.084794    0.377515  0.002049
# slug                          0.065166    0.337814  0.005089
# title                         0.086319    0.371199  0.002822
# type                         -0.050457    0.067729 -0.004308
# price                         0.043792    0.021337  0.005768
# timestamp                     0.038842    0.026065  0.005924
# posted_date                  -0.100369   -0.063521  0.006960
# deactivation_date            -0.032664   -0.011988  0.018137
# category                     -0.291554   -0.664129 -0.015006
# location                      0.035633    0.049089 -0.018519
# geo_region                   -0.298135   -0.191274  0.003751
# area                         -0.265541   -0.188131  0.006613
# is_member                     0.952283    0.340147  0.029623
# is_authorized_dealer          0.018962    0.010156  0.010350
# is_featured_member            0.010695    0.002010  0.002344
# is_verified                   0.737645    0.296904  0.028372
# membership_level              1.000000    0.296065  0.044708
# properties                    0.296065    1.000000  0.010825
# user                          0.044708    0.010825  1.000000

# %%
get = (correlation_matrix['price']>0.03) | (correlation_matrix['price']<-0.03)
get.sum()
# Out:
# 11

# %%
pred_colms = (get[get].index.to_list())
pred_colms
# Out:
# ['ad_title',
#  'slug',
#  'title',
#  'price',
#  'category',
#  'location',
#  'geo_region',
#  'area',
#  'is_member',
#  'is_verified',
#  'membership_level']

# %%
df_new1 = df[pred_colms]
df_new1.shape
# Out:
# (258875, 11)

# %%
# df_new1.drop(columns=['ad_title','posted_date','parent_category','is_delivery_free','deactivation_date','is_doorstep_delivery','is_doorstep_delivery','ad_description','is_dsd_applicable','slug', 'title', 'timestamp', 'area', 'properties', 'user'], inplace=True)

# %%
df_new1.head()
# Out:
#                                             ad_title  \
# 0     Nissan Tiida Alternator  in Maharagama | ikman
# 1              Axio 165 Tail Light  in Kotte | ikman
# 2     Axio 165 / 161 Head light  in Kotte | ikman.lk
# 3   Vigo side step ( Foot board)  in Kottawa | ikman
# 4  Vigo Dickey Door Garnish Cover  in Kottawa | i...
#
#                                                 slug  \
# 0         nissan-tiida-alternator-for-sale-colombo-3
# 1            axio-165-tail-light-for-sale-colombo-14
# 2           axio-165-161-head-light-for-sale-colombo
# 3         vigo-side-step-foot-board-for-sale-colombo
# 4  vigo-dickey-door-garnish-cover-for-sale-colombo-1
#
#                             title    price                  category  \
# 0         Nissan Tiida Alternator  18000.0  Auto Parts & Accessories
# 1             Axio 165 Tail Light  67000.0  Auto Parts & Accessories
# 2       Axio 165 / 161 Head light  85000.0  Auto Parts & Accessories
# 3    Vigo side step ( Foot board)  47000.0  Auto Parts & Accessories
# 4  Vigo Dickey Door Garnish Cover   9000.0  Auto Parts & Accessories
#
#      location geo_region                             area  is_member  \
# 0  Maharagama      LK-11  {'id': 1506, 'name': 'Colombo'}       True
# 1       Kotte      LK-11  {'id': 1506, 'name': 'Colombo'}       True
# 2       Kotte      LK-11  {'id': 1506, 'name': 'Colombo'}       True
# 3     Kottawa      LK-11  {'id': 1506, 'name': 'Colombo'}       True
# 4     Kottawa      LK-11  {'id': 1506, 'name': 'Colombo'}       True
#
#    is_verified membership_level
# 0         True          premium
# 1         True             plus
# 2         True             plus
# 3        False             plus
# 4        False             plus

# %% [markdown]
# -----------

# %%
categorical_features = ['ad_title',	'slug',	'title',	'category',	'location',	'geo_region',	'area',	'is_member',	'is_verified',	'membership_level']
label_encoders = {col: LabelEncoder() for col in categorical_features}

# %%
for col in categorical_features:
    df_new1[col] = label_encoders[col].fit_transform(df_new1[col])
# Out:
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\1060550478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new1[col] = label_encoders[col].fit_transform(df_new1[col])
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\1060550478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new1[col] = label_encoders[col].fit_transform(df_new1[col])
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\1060550478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new1[col] = label_encoders[col].fit_transform(df_new1[col])
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\1060550478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new1[col] = label_encoders[col].fit_transform(df_new1[col])
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\1060550478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new1[col] = label_encoders[col].fit_transform(df_new1[col])
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\1060550478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new1[col] = label_encoders[col].fit_transform(df_new1[col])
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\1060550478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new1[col] = label_encoders[col].fit_transform(df_new1[col])
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\1060550478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new1[col] = label_encoders[col].fit_transform(df_new1[col])
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\1060550478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new1[col] = label_encoders[col].fit_transform(df_new1[col])
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\1060550478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new1[col] = label_encoders[col].fit_transform(df_new1[col])

# %%
df_new1.head()
# Out:
#    ad_title    slug   title    price  category  location  geo_region  area  \
# 0    121151  160724   67713  18000.0         0       127           1     4
# 1     11730   13558    9903  67000.0         0       120           1     4
# 2     11712   13535    9886  85000.0         0       120           1     4
# 3    189641  246035  109459  47000.0         0       119           1     4
# 4    189613  246012  109432   9000.0         0       119           1     4
#
#    is_member  is_verified  membership_level
# 0          1            1                 2
# 1          1            1                 1
# 2          1            1                 1
# 3          1            0                 1
# 4          1            0                 1

# %%
numerical_features = ['ad_title','location','slug'	,'title','price']
scaler = StandardScaler()
df_new1[numerical_features] = scaler.fit_transform(df_new1[numerical_features])
# Out:
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_18376\183809776.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new1[numerical_features] = scaler.fit_transform(df_new1[numerical_features])

# %%
df_new1.head()
# Out:
#    ad_title      slug     title     price  category  location  geo_region  \
# 0  0.386869  0.418738  0.382004 -0.278796         0  0.394960           1
# 1 -1.476319 -1.550601 -1.309114 -0.272043         0  0.265149           1
# 2 -1.476626 -1.550909 -1.309612 -0.269562         0  0.265149           1
# 3  1.553096  1.560349  1.603202 -0.274799         0  0.246604           1
# 4  1.552619  1.560041  1.602412 -0.280036         0  0.246604           1
#
#    area  is_member  is_verified  membership_level
# 0     4          1            1                 2
# 1     4          1            1                 1
# 2     4          1            1                 1
# 3     4          1            0                 1
# 4     4          1            0                 1

# %%
plt.figure(figsize=(15, 10))
correlation_matrix = df_new1.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='inferno')
plt.show()

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
df_new1a = pd.DataFrame(df)

# %%
categorical_features = ['ad_title',	'ad_description',	'slug',	'title',	'type',	'timestamp',	'posted_date',	'deactivation_date',	'category',	'parent_category',	'location',	'geo_region',	'area',	'is_delivery_free',	'is_doorstep_delivery',	'is_dsd_applicable',	'is_member',	'is_authorized_dealer',	'is_featured_member',	'is_verified',	'membership_level',	'properties',	'user']
label_encoders = {col: LabelEncoder() for col in categorical_features}

for col in categorical_features:
    df_new1a[col] = label_encoders[col].fit_transform(df_new1a[col])

# %%
X = df_new1a.drop('price', axis=1)
y = df_new1a['price']

# %%
lasso = Lasso(alpha=0.01)
lasso.fit(X, y)
model = SelectFromModel(lasso, prefit=True)
X_selected = model.transform(X)

selected_features = X.columns[(model.get_support())]
print("Selected features:", selected_features)
# Out:
# Selected features: Index(['ad_title', 'ad_description', 'slug', 'title', 'type', 'timestamp',
#        'posted_date', 'deactivation_date', 'category', 'location',
#        'geo_region', 'area', 'is_member', 'is_authorized_dealer',
#        'is_featured_member', 'is_verified', 'membership_level', 'properties',
#        'user'],
#       dtype='object')
# C:\Users\PC-ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.611e+18, tolerance: 1.363e+15
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\PC-ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
X_selected = pd.DataFrame(X_selected, columns=selected_features)

# %% [markdown]
# ---------

# %% [markdown]
# 3.	Model Training:
#
#     ○	Train at least three different regression models
#
#     ○	Evaluate the models using cross-validation.

# %% [markdown]
# --------

# %% [markdown]
# ----------

# %% [markdown]
# a) Train at least three different regression models

# %% [markdown]
# --------

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=0)

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Decision Tree': DecisionTreeRegressor(),
    'Random Forest': RandomForestRegressor(),
}

# %% [markdown]
# ---------

# %% [markdown]
# b) Evaluate the models using cross-validation.

# %% [markdown]
# --------

# %% [markdown]
# 5.	Model Evaluation:
#
#     ○	Compare the models based on RMSE, MAE, and R².
#
#     ○	Select the best-performing model.

# %% [markdown]
# ---------

# %%
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    results[name] = {
        'RMSE': mean_squared_error(y_test, y_pred, squared=False),
        'MAE': mean_absolute_error(y_test, y_pred),
        'R²': r2_score(y_test, y_pred)
    }
# Out:
# C:\Users\PC-ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# C:\Users\PC-ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# C:\Users\PC-ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
for name, metrics in results.items():
    print(f"{name}:")
    for metric, value in metrics.items():
        print(f"  {metric}: {value:.4f}")
# Out:
# Linear Regression:
#   RMSE: 5710329.8940
#   MAE: 2409778.5295
#   R²: 0.0444
# Decision Tree:
#   RMSE: 4744823.1423
#   MAE: 519597.1764
#   R²: 0.3403
# Random Forest:
#   RMSE: 3108909.5088
#   MAE: 426133.3685
#   R²: 0.7168

# %% [markdown]
# ------

# %% [markdown]
# The best model as we can see from R2, which is 0.7168 which is best out of three models.

# %% [markdown]
# --------

# %% [markdown]
# 4.	Hyperparameter Tuning:
#
#     ○	Use Grid Search or Random Search for hyperparameter optimization

# %% [markdown]
# --------

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
grid_search = GridSearchCV(estimator=RandomForestRegressor(), param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

# %% [markdown]
# ----------

# %% [markdown]
# best parameter

# %% [markdown]
# ------

# %%
print("Best parameters:", grid_search.best_params_)

# %%
best_rf = grid_search.best_estimator_

# %%
y_pred_best_rf = best_rf.predict(X_test)

# %%
y_pred_best_rf = best_rf.predict(X_test)
print("Best Random Forest Model:")
print(f"  RMSE: {mean_squared_error(y_test, y_pred_best_rf, squared=False):.4f}")
print(f"  MAE: {mean_absolute_error(y_test, y_pred_best_rf):.4f}")
print(f"  R²: {r2_score(y_test, y_pred_best_rf):.4f}")

# %% [markdown]
# ------

# %% [markdown]
# SUMMARY
# ---

# %% [markdown]
# ----------

# %% [markdown]
# 1)Data Preprocessing:
#
#     We handled missing values, encoded categorical variables using LabelEncoder, and normalized numerical features using StandardScaler.
#
# 2)Feature Selection:
#
#     We performed correlation analysis and used Lasso regression for feature selection, identifying relevant features. In correlation analysis we found that only 11 columns were significantly impacting the target variable and using Lasso regression we found 19 columns were impacting signicantly target variables. Through correlation we foound the best model was Random Forest having accuracy of 68% and through Lasso regression it was found that it had an accuracy of 71.68% and best model was Random Forest.
#
# 3)Model Training:
#
#     We trained and evaluated Linear Regression, Decision Tree and Random Forest.
# 4)Hyperparameter Tuning:
#
#     We optimized the Random Forest model using Grid Search, achieving the best performance.
# 5) Conclusion:
#
#    We predicted with an accuracy of 71.68%, which is a good accuracy.

# %% [markdown]
# ----------

# %% [markdown]
# ----------

# %% [markdown]
# ----------

# %% [markdown]
# Section 2: User Segmentation
# -------

# %% [markdown]
# 1.	Data Preprocessing:
#
#     ○	Handle missing values.
#
#     ○	Encode categorical variables.

# %% [markdown]
# Already done.

# %% [markdown]
# ----------

# %% [markdown]
# 2.	Feature Selection:
#
#     ○	Use PCA to reduce dimensionality if necessary.
#
#     ○	Select relevant features for clustering.

# %%
df_new2 = pd.DataFrame(df)

# %%
df_new2.head()
# Out:
#                                             ad_title  \
# 0     Nissan Tiida Alternator  in Maharagama | ikman
# 1              Axio 165 Tail Light  in Kotte | ikman
# 2     Axio 165 / 161 Head light  in Kotte | ikman.lk
# 3   Vigo side step ( Foot board)  in Kottawa | ikman
# 4  Vigo Dickey Door Garnish Cover  in Kottawa | i...
#
#                                       ad_description  \
# 0  **TISSA AUTO PARTS** Dealer of used Japanese m...
# 1  Imported from Japan \n\nRight side available \...
# 2  Imported from Japan \n\nAuto focus headlight a...
# 3  Hilux Vigo side step\nBrand New Thaiwan\nGood ...
# 4  Hilux Vigo ( 2005, 2009 ) dickey door garnish set
#
#                                                 slug  \
# 0         nissan-tiida-alternator-for-sale-colombo-3
# 1            axio-165-tail-light-for-sale-colombo-14
# 2           axio-165-161-head-light-for-sale-colombo
# 3         vigo-side-step-foot-board-for-sale-colombo
# 4  vigo-dickey-door-garnish-cover-for-sale-colombo-1
#
#                             title      type    price        timestamp  \
# 0         Nissan Tiida Alternator  for_sale  18000.0  23 Feb 11:35 pm
# 1             Axio 165 Tail Light  for_sale  67000.0   23 Feb 8:32 am
# 2       Axio 165 / 161 Head light  for_sale  85000.0   01 Dec 8:27 pm
# 3    Vigo side step ( Foot board)  for_sale  47000.0   04 Dec 2:47 pm
# 4  Vigo Dickey Door Garnish Cover  for_sale   9000.0   08 Dec 9:28 am
#
#                  posted_date         deactivation_date  \
# 0  2023-02-23T23:35:10+05:30  2022-05-30T17:13:04.000Z
# 1  2023-02-23T08:32:44+05:30  2022-03-31T16:27:59.000Z
# 2  2022-12-01T20:27:49+05:30  2022-03-31T14:03:57.000Z
# 3  2022-12-04T14:47:27+05:30  2022-07-29T13:22:59.000Z
# 4  2022-12-08T09:28:04+05:30  2022-07-29T12:55:44.000Z
#
#                    category parent_category    location geo_region  \
# 0  Auto Parts & Accessories        Vehicles  Maharagama      LK-11
# 1  Auto Parts & Accessories        Vehicles       Kotte      LK-11
# 2  Auto Parts & Accessories        Vehicles       Kotte      LK-11
# 3  Auto Parts & Accessories        Vehicles     Kottawa      LK-11
# 4  Auto Parts & Accessories        Vehicles     Kottawa      LK-11
#
#                               area  is_delivery_free  is_doorstep_delivery  \
# 0  {'id': 1506, 'name': 'Colombo'}             False                 False
# 1  {'id': 1506, 'name': 'Colombo'}             False                 False
# 2  {'id': 1506, 'name': 'Colombo'}             False                 False
# 3  {'id': 1506, 'name': 'Colombo'}             False                 False
# 4  {'id': 1506, 'name': 'Colombo'}             False                 False
#
#    is_dsd_applicable  is_member  is_authorized_dealer  is_featured_member  \
# 0              False       True                 False               False
# 1              False       True                 False               False
# 2              False       True                 False               False
# 3              False       True                 False               False
# 4              False       True                 False               False
#
#    is_verified membership_level  \
# 0         True          premium
# 1         True             plus
# 2         True             plus
# 3        False             plus
# 4        False             plus
#
#                                           properties  \
# 0  {'Condition': 'Reconditioned', 'Part or Access...
# 1  {'Condition': 'Reconditioned', 'Part or Access...
# 2  {'Condition': 'Reconditioned', 'Part or Access...
# 3  {'Condition': 'New', 'Part or Accessory Type':...
# 4  {'Condition': 'New', 'Part or Accessory Type':...
#
#                                                 user
# 0  a6681dea494390daa516a6d2bdcb36e08c318574a13413...
# 1  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 2  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 3  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...
# 4  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...

# %%
df_new2.drop(columns=['parent_category'])
# Out:
#                                                  ad_title  \
# 0          Nissan Tiida Alternator  in Maharagama | ikman
# 1                   Axio 165 Tail Light  in Kotte | ikman
# 2          Axio 165 / 161 Head light  in Kotte | ikman.lk
# 3        Vigo side step ( Foot board)  in Kottawa | ikman
# 4       Vigo Dickey Door Garnish Cover  in Kottawa | i...
# ...                                                   ...
# 258883      Nissan March K10 1989  in Jaffna City | ikman
# 258884    Toyota Allion 260 2009  in Battaramulla | ikman
# 258885      Micro Trend Car for Rent in Colombo 3 | ikman
# 258886  Toyota Roomy custom GS safety 2018  in Borales...
# 258887           TVS Star Sport 2007  in Kekirawa | ikman
#
#                                            ad_description  \
# 0       **TISSA AUTO PARTS** Dealer of used Japanese m...
# 1       Imported from Japan \n\nRight side available \...
# 2       Imported from Japan \n\nAuto focus headlight a...
# 3       Hilux Vigo side step\nBrand New Thaiwan\nGood ...
# 4       Hilux Vigo ( 2005, 2009 ) dickey door garnish set
# ...                                                   ...
# 258883  Very good condition\nno hidden errors\nsmooth ...
# 258884  Good Conditions Car\nGenuine mileage \nManufac...
# 258885  Unlimited km\nPer month 70000\nManual transmis...
# 258886  Toyota Roomy Custom G\n2018 Model year \nMilea...
# 258887  engine hirawela 40 wiyadankarala hadhala thiye...
#
#                                                      slug  \
# 0              nissan-tiida-alternator-for-sale-colombo-3
# 1                 axio-165-tail-light-for-sale-colombo-14
# 2                axio-165-161-head-light-for-sale-colombo
# 3              vigo-side-step-foot-board-for-sale-colombo
# 4       vigo-dickey-door-garnish-cover-for-sale-colombo-1
# ...                                                   ...
# 258883              nissan-march-k10-1989-for-sale-jaffna
# 258884         toyota-allion-260-2009-for-sale-colombo-83
# 258885  micro-trend-unlimited-km-car-for-rent-for-sale...
# 258886  toyota-roomy-custom-gs-safety-2018-for-sale-co...
# 258887        tvs-star-sport-2007-for-sale-anuradhapura-6
#
#                                      title      type      price  \
# 0                  Nissan Tiida Alternator  for_sale    18000.0
# 1                      Axio 165 Tail Light  for_sale    67000.0
# 2                Axio 165 / 161 Head light  for_sale    85000.0
# 3             Vigo side step ( Foot board)  for_sale    47000.0
# 4           Vigo Dickey Door Garnish Cover  for_sale     9000.0
# ...                                    ...       ...        ...
# 258883               Nissan March K10 1989  for_sale  1030000.0
# 258884              Toyota Allion 260 2009  for_sale  3550000.0
# 258885            Micro Trend Car for Rent  for_sale    70000.0
# 258886  Toyota Roomy custom GS safety 2018  for_sale  7250000.0
# 258887                 TVS Star Sport 2007  for_sale   135000.0
#
#               timestamp                posted_date         deactivation_date  \
# 0       23 Feb 11:35 pm  2023-02-23T23:35:10+05:30  2022-05-30T17:13:04.000Z
# 1        23 Feb 8:32 am  2023-02-23T08:32:44+05:30  2022-03-31T16:27:59.000Z
# 2        01 Dec 8:27 pm  2022-12-01T20:27:49+05:30  2022-03-31T14:03:57.000Z
# 3        04 Dec 2:47 pm  2022-12-04T14:47:27+05:30  2022-07-29T13:22:59.000Z
# 4        08 Dec 9:28 am  2022-12-08T09:28:04+05:30  2022-07-29T12:55:44.000Z
# ...                 ...                        ...                       ...
# 258883  01 Apr 11:41 am  2023-04-01T11:41:50+05:30  2023-05-31T06:11:16.000Z
# 258884  30 Mar 10:10 am  2023-03-30T10:10:04+05:30  2023-05-29T04:36:57.000Z
# 258885  01 Apr 11:41 am  2023-04-01T11:41:13+05:30  2023-05-31T06:10:48.000Z
# 258886  01 Apr 11:40 am  2023-04-01T11:40:57+05:30  2023-05-31T06:10:57.000Z
# 258887  01 Apr 11:40 am  2023-04-01T11:40:56+05:30  2023-05-31T06:10:26.000Z
#
#                         category       location geo_region  \
# 0       Auto Parts & Accessories     Maharagama      LK-11
# 1       Auto Parts & Accessories          Kotte      LK-11
# 2       Auto Parts & Accessories          Kotte      LK-11
# 3       Auto Parts & Accessories        Kottawa      LK-11
# 4       Auto Parts & Accessories        Kottawa      LK-11
# ...                          ...            ...        ...
# 258883                      Cars    Jaffna City      LK-41
# 258884                      Cars   Battaramulla      LK-11
# 258885                   Rentals      Colombo 3      LK-11
# 258886                      Cars  Boralesgamuwa      LK-11
# 258887                Motorbikes       Kekirawa      LK-71
#
#                                         area  is_delivery_free  \
# 0            {'id': 1506, 'name': 'Colombo'}             False
# 1            {'id': 1506, 'name': 'Colombo'}             False
# 2            {'id': 1506, 'name': 'Colombo'}             False
# 3            {'id': 1506, 'name': 'Colombo'}             False
# 4            {'id': 1506, 'name': 'Colombo'}             False
# ...                                      ...               ...
# 258883        {'id': 1605, 'name': 'Jaffna'}             False
# 258884       {'id': 1506, 'name': 'Colombo'}             False
# 258885       {'id': 1506, 'name': 'Colombo'}             False
# 258886       {'id': 1506, 'name': 'Colombo'}             False
# 258887  {'id': 1452, 'name': 'Anuradhapura'}             False
#
#         is_doorstep_delivery  is_dsd_applicable  is_member  \
# 0                      False              False       True
# 1                      False              False       True
# 2                      False              False       True
# 3                      False              False       True
# 4                      False              False       True
# ...                      ...                ...        ...
# 258883                 False              False      False
# 258884                 False              False      False
# 258885                 False              False      False
# 258886                 False              False       True
# 258887                 False              False      False
#
#         is_authorized_dealer  is_featured_member  is_verified  \
# 0                      False               False         True
# 1                      False               False         True
# 2                      False               False         True
# 3                      False               False        False
# 4                      False               False        False
# ...                      ...                 ...          ...
# 258883                 False               False        False
# 258884                 False               False        False
# 258885                 False               False        False
# 258886                 False               False        False
# 258887                 False               False        False
#
#        membership_level                                         properties  \
# 0               premium  {'Condition': 'Reconditioned', 'Part or Access...
# 1                  plus  {'Condition': 'Reconditioned', 'Part or Access...
# 2                  plus  {'Condition': 'Reconditioned', 'Part or Access...
# 3                  plus  {'Condition': 'New', 'Part or Accessory Type':...
# 4                  plus  {'Condition': 'New', 'Part or Accessory Type':...
# ...                 ...                                                ...
# 258883             free  {'Brand': 'Nissan', 'Model': 'March', 'Trim / ...
# 258884             free  {'Brand': 'Toyota', 'Model': 'Allion', 'Trim /...
# 258885             free                    {'Service type': 'Car Rentals'}
# 258886          premium  {'Brand': 'Toyota', 'Model': 'Roomy', 'Trim / ...
# 258887             free  {'Bike Type': 'Motorbikes', 'Condition': 'Used...
#
#                                                      user
# 0       a6681dea494390daa516a6d2bdcb36e08c318574a13413...
# 1       5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 2       5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 3       634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...
# 4       634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...
# ...                                                   ...
# 258883  48a910425b8f190b818a89d56b60a919c8b5297b0208ea...
# 258884  c9b739e56cdac87b2a966a338eb8508c15dd977445751b...
# 258885  c7bf4bbdbcd88d9d7f7c7b299c94e9e52091af2fd2888e...
# 258886  7c6477247c19fa63845687656fee40702da46c9d184568...
# 258887  250f50f6456508d02d1f94e93cf90bfe5659696d70e5d2...
#
# [258875 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# ad_title                0
# ad_description          0
# slug                    0
# title                   0
# type                    0
# price                   0
# timestamp               0
# posted_date             0
# deactivation_date       0
# category                0
# parent_category         0
# location                0
# geo_region              0
# area                    0
# is_delivery_free        0
# is_doorstep_delivery    0
# is_dsd_applicable       0
# is_member               0
# is_authorized_dealer    0
# is_featured_member      0
# is_verified             0
# membership_level        0
# properties              0
# user                    0
# dtype: int64

# %%
df_new2['posted_date'] = pd.to_datetime(df_new2['posted_date'], errors='coerce')
df_new2['deactivation_date'] = pd.to_datetime(df_new2['deactivation_date'], errors='coerce')
df_new2['posted_date'] = df_new2['posted_date'].dt.date
df_new2['deactivation_date'] = df_new2['deactivation_date'].dt.date

# %%
idx = np.where(df_new2.posted_date>df_new2.deactivation_date)[0]

df_new2['posted_date'].iloc[idx], df_new2['deactivation_date'].iloc[idx] = df_new2['deactivation_date'].iloc[idx], df_new2['posted_date'].iloc[idx]

# %%
df_new2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258875 entries, 0 to 258887
# Data columns (total 24 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ad_title              258875 non-null  object
#  1   ad_description        258875 non-null  object
#  2   slug                  258875 non-null  object
#  3   title                 258875 non-null  object
#  4   type                  258875 non-null  object
#  5   price                 258875 non-null  float64
#  6   timestamp             258875 non-null  object
#  7   posted_date           258875 non-null  object
#  8   deactivation_date     258875 non-null  object
#  9   category              258875 non-null  object
#  10  parent_category       258875 non-null  object
#  11  location              258875 non-null  object
#  12  geo_region            258875 non-null  object
#  13  area                  258875 non-null  object
#  14  is_delivery_free      258875 non-null  bool
#  15  is_doorstep_delivery  258875 non-null  bool
#  16  is_dsd_applicable     258875 non-null  bool
#  17  is_member             258875 non-null  bool
#  18  is_authorized_dealer  258875 non-null  bool
#  19  is_featured_member    258875 non-null  bool
#  20  is_verified           258875 non-null  bool
#  21  membership_level      258875 non-null  object
#  22  properties            258875 non-null  object
#  23  user                  258875 non-null  object
# dtypes: bool(7), float64(1), object(16)
# memory usage: 37.3+ MB

# %%
df_new2.head()
# Out:
#                                             ad_title  \
# 0     Nissan Tiida Alternator  in Maharagama | ikman
# 1              Axio 165 Tail Light  in Kotte | ikman
# 2     Axio 165 / 161 Head light  in Kotte | ikman.lk
# 3   Vigo side step ( Foot board)  in Kottawa | ikman
# 4  Vigo Dickey Door Garnish Cover  in Kottawa | i...
#
#                                       ad_description  \
# 0  **TISSA AUTO PARTS** Dealer of used Japanese m...
# 1  Imported from Japan \n\nRight side available \...
# 2  Imported from Japan \n\nAuto focus headlight a...
# 3  Hilux Vigo side step\nBrand New Thaiwan\nGood ...
# 4  Hilux Vigo ( 2005, 2009 ) dickey door garnish set
#
#                                                 slug  \
# 0         nissan-tiida-alternator-for-sale-colombo-3
# 1            axio-165-tail-light-for-sale-colombo-14
# 2           axio-165-161-head-light-for-sale-colombo
# 3         vigo-side-step-foot-board-for-sale-colombo
# 4  vigo-dickey-door-garnish-cover-for-sale-colombo-1
#
#                             title      type    price        timestamp  \
# 0         Nissan Tiida Alternator  for_sale  18000.0  23 Feb 11:35 pm
# 1             Axio 165 Tail Light  for_sale  67000.0   23 Feb 8:32 am
# 2       Axio 165 / 161 Head light  for_sale  85000.0   01 Dec 8:27 pm
# 3    Vigo side step ( Foot board)  for_sale  47000.0   04 Dec 2:47 pm
# 4  Vigo Dickey Door Garnish Cover  for_sale   9000.0   08 Dec 9:28 am
#
#   posted_date deactivation_date                  category parent_category  \
# 0  2022-05-30        2023-02-23  Auto Parts & Accessories        Vehicles
# 1  2022-03-31        2023-02-23  Auto Parts & Accessories        Vehicles
# 2  2022-03-31        2022-12-01  Auto Parts & Accessories        Vehicles
# 3  2022-07-29        2022-12-04  Auto Parts & Accessories        Vehicles
# 4  2022-07-29        2022-12-08  Auto Parts & Accessories        Vehicles
#
#      location geo_region                             area  is_delivery_free  \
# 0  Maharagama      LK-11  {'id': 1506, 'name': 'Colombo'}             False
# 1       Kotte      LK-11  {'id': 1506, 'name': 'Colombo'}             False
# 2       Kotte      LK-11  {'id': 1506, 'name': 'Colombo'}             False
# 3     Kottawa      LK-11  {'id': 1506, 'name': 'Colombo'}             False
# 4     Kottawa      LK-11  {'id': 1506, 'name': 'Colombo'}             False
#
#    is_doorstep_delivery  is_dsd_applicable  is_member  is_authorized_dealer  \
# 0                 False              False       True                 False
# 1                 False              False       True                 False
# 2                 False              False       True                 False
# 3                 False              False       True                 False
# 4                 False              False       True                 False
#
#    is_featured_member  is_verified membership_level  \
# 0               False         True          premium
# 1               False         True             plus
# 2               False         True             plus
# 3               False        False             plus
# 4               False        False             plus
#
#                                           properties  \
# 0  {'Condition': 'Reconditioned', 'Part or Access...
# 1  {'Condition': 'Reconditioned', 'Part or Access...
# 2  {'Condition': 'Reconditioned', 'Part or Access...
# 3  {'Condition': 'New', 'Part or Accessory Type':...
# 4  {'Condition': 'New', 'Part or Accessory Type':...
#
#                                                 user
# 0  a6681dea494390daa516a6d2bdcb36e08c318574a13413...
# 1  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 2  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 3  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...
# 4  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...

# %%
for col in categorical_features:
    df_new2[col] = label_encoders[col].fit_transform(df_new2[col])

# %% [markdown]
# -------

# %% [markdown]
# 2.	Feature Selection:
#
#     ○	Use PCA to reduce dimensionality if necessary.
#
#     ○	Select relevant features for clustering.

# %% [markdown]
# -----------

# %%
from sklearn.decomposition import PCA

# %%
features_for_clustering = ['type', 'category', 'location', 'geo_region', 'membership_level', 'is_member', 'is_authorized_dealer', 'is_featured_member']
X_clustering = df_new2[features_for_clustering]

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_clustering)

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1])
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('PCA of User Features')
plt.show()

# %% [markdown]
# ---------

# %% [markdown]
# 3.	Clustering:
#
#     ○	Apply K-means clustering to segment users.
#
#     ○	Experiment with different numbers of clusters and evaluate using the Elbow Method and Silhouette Score.

# %% [markdown]
# ----------

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
iner = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_pca)
    iner.append(kmeans.inertia_)

# %%
plt.plot(range(2, 11), iner, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()

# %% [markdown]
# -----------

# %% [markdown]
#  a) Apply K-means clustering

# %% [markdown]
# ---------

# %%
optimal_k = 4
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
clusters = kmeans.fit_predict(X_pca)

# %%
silhouette_avg = silhouette_score(X_pca, clusters)
print(f"Silhouette Score: {silhouette_avg:.4f}")
# Out:
# Silhouette Score: 0.5478

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='viridis')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('User Clusters')
plt.show()

# %% [markdown]
# ---------

# %% [markdown]
# 4.	Cluster Analysis:
#
#     ○	Interpret and describe the characteristics of each cluster.
#
#     ○	Identify any patterns or insights about user behavior.

# %% [markdown]
# ------------

# %%
df_new2['cluster'] = clusters

# %%
for cluster in range(optimal_k):
    cluster_data = df_new2[df_new2['cluster'] == cluster]
    print(f"Cluster {cluster}:")
    print(cluster_data[features_for_clustering].mean())
# Out:
# Cluster 0:
# type                      0.003543
# category                  4.968830
# location                121.702906
# geo_region                4.684155
# membership_level          0.832958
# is_member                 0.455285
# is_authorized_dealer      0.000000
# is_featured_member        0.000179
# dtype: float64
# Cluster 1:
# type                     0.005726
# category                 5.254591
# location                28.990752
# geo_region               4.354033
# membership_level         0.706964
# is_member                0.391593
# is_authorized_dealer     0.000735
# is_featured_member       0.000000
# dtype: float64
# Cluster 2:
# type                      0.003869
# category                  4.702594
# location                171.164894
# geo_region                4.104670
# membership_level          0.673639
# is_member                 0.382558
# is_authorized_dealer      0.000000
# is_featured_member        0.000000
# dtype: float64
# Cluster 3:
# type                     0.005242
# category                 5.382695
# location                81.254690
# geo_region               3.821688
# membership_level         0.447584
# is_member                0.253310
# is_authorized_dealer     0.000000
# is_featured_member       0.000000
# dtype: float64

# %% [markdown]
# ----------

# %% [markdown]
# # Summary

# %% [markdown]
# ---------

# %% [markdown]
# Data Preprocessing:
#
#     Handling Missing Values: The dataset contains several missing values, particularly in the details and member_since columns. Missing details and price were imputed using median values. Categorical columns with missing values were filled with 'Unknown'.

# %% [markdown]
# Feature Selection:
#
#     Selection of Clustering Features: The features chosen for clustering were price and kilometers_run. These features were selected based on their relevance to the clustering objective and their data quality.

# %% [markdown]
# --------

# %% [markdown]
# Cluster Analysis:
#
# Cluster 0:
#
#     Characteristics: [Describe the mean values and other notable features of this cluster]
#     Business Implications: [Discuss potential actions or strategies tailored for this segment]
#
# Cluster 1:
#
#     Characteristics: [Describe the mean values and other notable features of this cluster]
#     Business Implications: [Discuss potential actions or strategies tailored for this segment]
#
# Cluster 2:
#
#     Characteristics: [Describe the mean values and other notable features of this cluster]
#     Business Implications: [Discuss potential actions or strategies tailored for this segment]
#
# Cluster 3:
#
#     Characteristics: [Describe the mean values and other notable features of this cluster]
#     Business Implications: [Discuss potential actions or strategies tailored for this segment]

# %% [markdown]
# --------

# %% [markdown]
# Sample Business Implications:
#
# Targeted Marketing:
#
#     Segment-specific promotions and advertisements can be created to cater to the specific needs and preferences of each user segment.
#
# Product Recommendations:
#
#     Personalized vehicle or accessory recommendations can be made based on the typical price range and kilometers run in each cluster.
#
# Pricing Strategy:
#
#     Adjust pricing strategies based on the demand characteristics observed in each segment to maximize sales and profit margins.
#
# Enhanced Customer Experience:
#
#     Improve the customer experience by understanding and addressing the unique concerns and preferences of different user segments. By performing these analyses and generating actionable insights, you can develop targeted strategies to enhance customer satisfaction, optimize pricing, and improve overall business performance.

# %% [markdown]
# ------------

# %% [markdown]
# ------------------

# %% [markdown]
# # Section 3: Geographical Analysis of Demand and Supply

# %% [markdown]
# -------------

# %% [markdown]
# -------------------

# %% [markdown]
# 1.	Data Preprocessing:
#
#     ○	Handle missing values.
#
#     ○	Encode geographical variables

# %% [markdown]
# --------------

# %% [markdown]
# Already handled missing values

# %%
df_new3 = pd.DataFrame(df)

# %%
df_new3.head()
# Out:
#                                             ad_title  \
# 0     Nissan Tiida Alternator  in Maharagama | ikman
# 1              Axio 165 Tail Light  in Kotte | ikman
# 2     Axio 165 / 161 Head light  in Kotte | ikman.lk
# 3   Vigo side step ( Foot board)  in Kottawa | ikman
# 4  Vigo Dickey Door Garnish Cover  in Kottawa | i...
#
#                                       ad_description  \
# 0  **TISSA AUTO PARTS** Dealer of used Japanese m...
# 1  Imported from Japan \n\nRight side available \...
# 2  Imported from Japan \n\nAuto focus headlight a...
# 3  Hilux Vigo side step\nBrand New Thaiwan\nGood ...
# 4  Hilux Vigo ( 2005, 2009 ) dickey door garnish set
#
#                                                 slug  \
# 0         nissan-tiida-alternator-for-sale-colombo-3
# 1            axio-165-tail-light-for-sale-colombo-14
# 2           axio-165-161-head-light-for-sale-colombo
# 3         vigo-side-step-foot-board-for-sale-colombo
# 4  vigo-dickey-door-garnish-cover-for-sale-colombo-1
#
#                             title      type    price        timestamp  \
# 0         Nissan Tiida Alternator  for_sale  18000.0  23 Feb 11:35 pm
# 1             Axio 165 Tail Light  for_sale  67000.0   23 Feb 8:32 am
# 2       Axio 165 / 161 Head light  for_sale  85000.0   01 Dec 8:27 pm
# 3    Vigo side step ( Foot board)  for_sale  47000.0   04 Dec 2:47 pm
# 4  Vigo Dickey Door Garnish Cover  for_sale   9000.0   08 Dec 9:28 am
#
#                  posted_date         deactivation_date  \
# 0  2023-02-23T23:35:10+05:30  2022-05-30T17:13:04.000Z
# 1  2023-02-23T08:32:44+05:30  2022-03-31T16:27:59.000Z
# 2  2022-12-01T20:27:49+05:30  2022-03-31T14:03:57.000Z
# 3  2022-12-04T14:47:27+05:30  2022-07-29T13:22:59.000Z
# 4  2022-12-08T09:28:04+05:30  2022-07-29T12:55:44.000Z
#
#                    category parent_category    location geo_region  \
# 0  Auto Parts & Accessories        Vehicles  Maharagama      LK-11
# 1  Auto Parts & Accessories        Vehicles       Kotte      LK-11
# 2  Auto Parts & Accessories        Vehicles       Kotte      LK-11
# 3  Auto Parts & Accessories        Vehicles     Kottawa      LK-11
# 4  Auto Parts & Accessories        Vehicles     Kottawa      LK-11
#
#                               area  is_delivery_free  is_doorstep_delivery  \
# 0  {'id': 1506, 'name': 'Colombo'}             False                 False
# 1  {'id': 1506, 'name': 'Colombo'}             False                 False
# 2  {'id': 1506, 'name': 'Colombo'}             False                 False
# 3  {'id': 1506, 'name': 'Colombo'}             False                 False
# 4  {'id': 1506, 'name': 'Colombo'}             False                 False
#
#    is_dsd_applicable  is_member  is_authorized_dealer  is_featured_member  \
# 0              False       True                 False               False
# 1              False       True                 False               False
# 2              False       True                 False               False
# 3              False       True                 False               False
# 4              False       True                 False               False
#
#    is_verified membership_level  \
# 0         True          premium
# 1         True             plus
# 2         True             plus
# 3        False             plus
# 4        False             plus
#
#                                           properties  \
# 0  {'Condition': 'Reconditioned', 'Part or Access...
# 1  {'Condition': 'Reconditioned', 'Part or Access...
# 2  {'Condition': 'Reconditioned', 'Part or Access...
# 3  {'Condition': 'New', 'Part or Accessory Type':...
# 4  {'Condition': 'New', 'Part or Accessory Type':...
#
#                                                 user
# 0  a6681dea494390daa516a6d2bdcb36e08c318574a13413...
# 1  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 2  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 3  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...
# 4  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...

# %% [markdown]
# ---------

# %% [markdown]
# b) Encode geographical variables

# %% [markdown]
# ----------

# %%
from sklearn.preprocessing import LabelEncoder

# %%
geo_features = ['location', 'geo_region', 'area']
for col in geo_features:
    df[col] = label_encoders[col].fit_transform(df[col])

print(df.head())
# Out:
#                                             ad_title  \
# 0     Nissan Tiida Alternator  in Maharagama | ikman
# 1              Axio 165 Tail Light  in Kotte | ikman
# 2     Axio 165 / 161 Head light  in Kotte | ikman.lk
# 3   Vigo side step ( Foot board)  in Kottawa | ikman
# 4  Vigo Dickey Door Garnish Cover  in Kottawa | i...
#
#                                       ad_description  \
# 0  **TISSA AUTO PARTS** Dealer of used Japanese m...
# 1  Imported from Japan \n\nRight side available \...
# 2  Imported from Japan \n\nAuto focus headlight a...
# 3  Hilux Vigo side step\nBrand New Thaiwan\nGood ...
# 4  Hilux Vigo ( 2005, 2009 ) dickey door garnish set
#
#                                                 slug  \
# 0         nissan-tiida-alternator-for-sale-colombo-3
# 1            axio-165-tail-light-for-sale-colombo-14
# 2           axio-165-161-head-light-for-sale-colombo
# 3         vigo-side-step-foot-board-for-sale-colombo
# 4  vigo-dickey-door-garnish-cover-for-sale-colombo-1
#
#                             title      type    price        timestamp  \
# 0         Nissan Tiida Alternator  for_sale  18000.0  23 Feb 11:35 pm
# 1             Axio 165 Tail Light  for_sale  67000.0   23 Feb 8:32 am
# 2       Axio 165 / 161 Head light  for_sale  85000.0   01 Dec 8:27 pm
# 3    Vigo side step ( Foot board)  for_sale  47000.0   04 Dec 2:47 pm
# 4  Vigo Dickey Door Garnish Cover  for_sale   9000.0   08 Dec 9:28 am
#
#                  posted_date         deactivation_date  \
# 0  2023-02-23T23:35:10+05:30  2022-05-30T17:13:04.000Z
# 1  2023-02-23T08:32:44+05:30  2022-03-31T16:27:59.000Z
# 2  2022-12-01T20:27:49+05:30  2022-03-31T14:03:57.000Z
# 3  2022-12-04T14:47:27+05:30  2022-07-29T13:22:59.000Z
# 4  2022-12-08T09:28:04+05:30  2022-07-29T12:55:44.000Z
#
#                    category parent_category  location  geo_region  area  \
# 0  Auto Parts & Accessories        Vehicles       127           1     4
# 1  Auto Parts & Accessories        Vehicles       120           1     4
# 2  Auto Parts & Accessories        Vehicles       120           1     4
# 3  Auto Parts & Accessories        Vehicles       119           1     4
# 4  Auto Parts & Accessories        Vehicles       119           1     4
#
#    is_delivery_free  is_doorstep_delivery  is_dsd_applicable  is_member  \
# 0             False                 False              False       True
# 1             False                 False              False       True
# 2             False                 False              False       True
# 3             False                 False              False       True
# 4             False                 False              False       True
#
#    is_authorized_dealer  is_featured_member  is_verified membership_level  \
# 0                 False               False         True          premium
# 1                 False               False         True             plus
# 2                 False               False         True             plus
# 3                 False               False        False             plus
# 4                 False               False        False             plus
#
#                                           properties  \
# 0  {'Condition': 'Reconditioned', 'Part or Access...
# 1  {'Condition': 'Reconditioned', 'Part or Access...
# 2  {'Condition': 'Reconditioned', 'Part or Access...
# 3  {'Condition': 'New', 'Part or Accessory Type':...
# 4  {'Condition': 'New', 'Part or Accessory Type':...
#
#                                                 user
# 0  a6681dea494390daa516a6d2bdcb36e08c318574a13413...
# 1  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 2  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 3  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...
# 4  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...

# %%
import geopandas as gpd

# %%
df_new3.head()
# Out:
#                                             ad_title  \
# 0     Nissan Tiida Alternator  in Maharagama | ikman
# 1              Axio 165 Tail Light  in Kotte | ikman
# 2     Axio 165 / 161 Head light  in Kotte | ikman.lk
# 3   Vigo side step ( Foot board)  in Kottawa | ikman
# 4  Vigo Dickey Door Garnish Cover  in Kottawa | i...
#
#                                       ad_description  \
# 0  **TISSA AUTO PARTS** Dealer of used Japanese m...
# 1  Imported from Japan \n\nRight side available \...
# 2  Imported from Japan \n\nAuto focus headlight a...
# 3  Hilux Vigo side step\nBrand New Thaiwan\nGood ...
# 4  Hilux Vigo ( 2005, 2009 ) dickey door garnish set
#
#                                                 slug  \
# 0         nissan-tiida-alternator-for-sale-colombo-3
# 1            axio-165-tail-light-for-sale-colombo-14
# 2           axio-165-161-head-light-for-sale-colombo
# 3         vigo-side-step-foot-board-for-sale-colombo
# 4  vigo-dickey-door-garnish-cover-for-sale-colombo-1
#
#                             title      type    price        timestamp  \
# 0         Nissan Tiida Alternator  for_sale  18000.0  23 Feb 11:35 pm
# 1             Axio 165 Tail Light  for_sale  67000.0   23 Feb 8:32 am
# 2       Axio 165 / 161 Head light  for_sale  85000.0   01 Dec 8:27 pm
# 3    Vigo side step ( Foot board)  for_sale  47000.0   04 Dec 2:47 pm
# 4  Vigo Dickey Door Garnish Cover  for_sale   9000.0   08 Dec 9:28 am
#
#                  posted_date         deactivation_date  \
# 0  2023-02-23T23:35:10+05:30  2022-05-30T17:13:04.000Z
# 1  2023-02-23T08:32:44+05:30  2022-03-31T16:27:59.000Z
# 2  2022-12-01T20:27:49+05:30  2022-03-31T14:03:57.000Z
# 3  2022-12-04T14:47:27+05:30  2022-07-29T13:22:59.000Z
# 4  2022-12-08T09:28:04+05:30  2022-07-29T12:55:44.000Z
#
#                    category parent_category  location  geo_region  area  \
# 0  Auto Parts & Accessories        Vehicles       127           1     4
# 1  Auto Parts & Accessories        Vehicles       120           1     4
# 2  Auto Parts & Accessories        Vehicles       120           1     4
# 3  Auto Parts & Accessories        Vehicles       119           1     4
# 4  Auto Parts & Accessories        Vehicles       119           1     4
#
#    is_delivery_free  is_doorstep_delivery  is_dsd_applicable  is_member  \
# 0             False                 False              False       True
# 1             False                 False              False       True
# 2             False                 False              False       True
# 3             False                 False              False       True
# 4             False                 False              False       True
#
#    is_authorized_dealer  is_featured_member  is_verified membership_level  \
# 0                 False               False         True          premium
# 1                 False               False         True             plus
# 2                 False               False         True             plus
# 3                 False               False        False             plus
# 4                 False               False        False             plus
#
#                                           properties  \
# 0  {'Condition': 'Reconditioned', 'Part or Access...
# 1  {'Condition': 'Reconditioned', 'Part or Access...
# 2  {'Condition': 'Reconditioned', 'Part or Access...
# 3  {'Condition': 'New', 'Part or Accessory Type':...
# 4  {'Condition': 'New', 'Part or Accessory Type':...
#
#                                                 user
# 0  a6681dea494390daa516a6d2bdcb36e08c318574a13413...
# 1  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 2  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 3  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...
# 4  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...

# %%
df_new3['posted_date'] = pd.to_datetime(df_new3['posted_date'], errors='coerce')
df_new3['deactivation_date'] = pd.to_datetime(df_new3['deactivation_date'], errors='coerce')
df_new3['posted_date'] = df_new3['posted_date'].dt.date
df_new3['deactivation_date'] = df_new3['deactivation_date'].dt.date

# %%
idx = np.where(df_new2.posted_date>df_new2.deactivation_date)[0]

df_new2['posted_date'].iloc[idx], df_new2['deactivation_date'].iloc[idx] = df_new2['deactivation_date'].iloc[idx], df_new2['posted_date'].iloc[idx]
# Out:
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_20788\2149781510.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_new2['posted_date'].iloc[idx], df_new2['deactivation_date'].iloc[idx] = df_new2['deactivation_date'].iloc[idx], df_new2['posted_date'].iloc[idx]
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_20788\2149781510.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new2['posted_date'].iloc[idx], df_new2['deactivation_date'].iloc[idx] = df_new2['deactivation_date'].iloc[idx], df_new2['posted_date'].iloc[idx]
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_20788\2149781510.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_new2['posted_date'].iloc[idx], df_new2['deactivation_date'].iloc[idx] = df_new2['deactivation_date'].iloc[idx], df_new2['posted_date'].iloc[idx]
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_20788\2149781510.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new2['posted_date'].iloc[idx], df_new2['deactivation_date'].iloc[idx] = df_new2['deactivation_date'].iloc[idx], df_new2['posted_date'].iloc[idx]

# %%
df_new3.head()
# Out:
#                                             ad_title  \
# 0     Nissan Tiida Alternator  in Maharagama | ikman
# 1              Axio 165 Tail Light  in Kotte | ikman
# 2     Axio 165 / 161 Head light  in Kotte | ikman.lk
# 3   Vigo side step ( Foot board)  in Kottawa | ikman
# 4  Vigo Dickey Door Garnish Cover  in Kottawa | i...
#
#                                       ad_description  \
# 0  **TISSA AUTO PARTS** Dealer of used Japanese m...
# 1  Imported from Japan \n\nRight side available \...
# 2  Imported from Japan \n\nAuto focus headlight a...
# 3  Hilux Vigo side step\nBrand New Thaiwan\nGood ...
# 4  Hilux Vigo ( 2005, 2009 ) dickey door garnish set
#
#                                                 slug  \
# 0         nissan-tiida-alternator-for-sale-colombo-3
# 1            axio-165-tail-light-for-sale-colombo-14
# 2           axio-165-161-head-light-for-sale-colombo
# 3         vigo-side-step-foot-board-for-sale-colombo
# 4  vigo-dickey-door-garnish-cover-for-sale-colombo-1
#
#                             title      type    price        timestamp  \
# 0         Nissan Tiida Alternator  for_sale  18000.0  23 Feb 11:35 pm
# 1             Axio 165 Tail Light  for_sale  67000.0   23 Feb 8:32 am
# 2       Axio 165 / 161 Head light  for_sale  85000.0   01 Dec 8:27 pm
# 3    Vigo side step ( Foot board)  for_sale  47000.0   04 Dec 2:47 pm
# 4  Vigo Dickey Door Garnish Cover  for_sale   9000.0   08 Dec 9:28 am
#
#   posted_date deactivation_date                  category parent_category  \
# 0  2023-02-23        2022-05-30  Auto Parts & Accessories        Vehicles
# 1  2023-02-23        2022-03-31  Auto Parts & Accessories        Vehicles
# 2  2022-12-01        2022-03-31  Auto Parts & Accessories        Vehicles
# 3  2022-12-04        2022-07-29  Auto Parts & Accessories        Vehicles
# 4  2022-12-08        2022-07-29  Auto Parts & Accessories        Vehicles
#
#    location  geo_region  area  is_delivery_free  is_doorstep_delivery  \
# 0       127           1     4             False                 False
# 1       120           1     4             False                 False
# 2       120           1     4             False                 False
# 3       119           1     4             False                 False
# 4       119           1     4             False                 False
#
#    is_dsd_applicable  is_member  is_authorized_dealer  is_featured_member  \
# 0              False       True                 False               False
# 1              False       True                 False               False
# 2              False       True                 False               False
# 3              False       True                 False               False
# 4              False       True                 False               False
#
#    is_verified membership_level  \
# 0         True          premium
# 1         True             plus
# 2         True             plus
# 3        False             plus
# 4        False             plus
#
#                                           properties  \
# 0  {'Condition': 'Reconditioned', 'Part or Access...
# 1  {'Condition': 'Reconditioned', 'Part or Access...
# 2  {'Condition': 'Reconditioned', 'Part or Access...
# 3  {'Condition': 'New', 'Part or Accessory Type':...
# 4  {'Condition': 'New', 'Part or Accessory Type':...
#
#                                                 user
# 0  a6681dea494390daa516a6d2bdcb36e08c318574a13413...
# 1  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 2  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 3  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...
# 4  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...

# %% [markdown]
# ------------
#
# 2.	Geographical Analysis:
#
#     ○	Visualize the distribution of advertisements across different regions.
#
#     ○	Identify regions with high demand and supply.
#
#
# ---------

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_counts = df.groupby('location').size().reset_index(name='ad_count')

# %%
plt.figure(figsize=(50, 10),dpi=300)
sns.barplot(x='location', y='ad_count', data=df_counts, palette='viridis')
plt.title('Distribution of Advertisements Across Locations')
plt.xlabel('Location')
plt.ylabel('Number of Advertisements')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_20788\1235352498.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='location', y='ad_count', data=df_counts, palette='viridis')

# %% [markdown]
# -----------
#
# 3.	Temporal Analysis:
#
#     ○	Analyze how demand and supply vary over time in different regions.
#
#     ○	Identify any seasonal trends or patterns.
#
# --------

# %%
df_new3['posted_date'] = pd.to_datetime(df_new3['posted_date'])
df_new3['posted_month'] = df_new3['posted_date'].dt.to_period('M')

# %%
monthly_counts = df_new3.groupby(['location', 'posted_month']).size().reset_index(name='count')

# %%
plt.figure(figsize=(12, 8))
for location in monthly_counts['location'].unique():
    location_data = monthly_counts[monthly_counts['location'] == location]
    plt.plot(location_data['posted_month'].astype(str), location_data['count'], marker='o', label=location)

plt.title('Monthly Distribution of Advertisements Across Locations')
plt.xlabel('Posted Month')
plt.ylabel('Number of Advertisements')
plt.xticks(rotation=45)
plt.legend(title='Location')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_20788\2936069593.py:11: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ------------
#
# # Summary
#
# ----------

# %% [markdown]
# Deliverables;
#
# a. Visualizations of geographical and temporal trends in demand and supply.
#
# b. A detailed report on the findings from the geographical analysis.
#
# c. Performance metrics of the demand and supply prediction model.
#
# d. Insights and recommendations based on the analysis.

# %% [markdown]
# ------------
# ------------
# -----------
# -----------
